# %%
from sklearn.ensemble import RandomForestClassifier
import pandas as pd
import optuna as opt
import pickle as pkl

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %%
rf = RandomForestClassifier(n_estimators=100, min_samples_split= 10 ,random_state=1)

# %%
match_data = pd.read_csv('fbref_prem_data.csv')

# %%
train_data = match_data[match_data['Date'] < "2023-01-01"]
test_data = match_data[match_data['Date'] >= "2023-01-01"]

# %%
predictors = ['Opp_Code', 'Venue_Code', 'GF_rolling', 'GA_rolling', 'Poss_rolling', 'xG_rolling',
       'xGA_rolling', 'Sh_rolling', 'SoT_rolling', 'Dist_rolling',
       'SoTA_rolling', 'Cmp_rolling', 'Att_rolling', 'TotDist_rolling',
       'PrgDist_rolling', 'SCA_rolling', 'GCA_rolling']

# %%
rf.fit(train_data[predictors], train_data['Simple Target'])
# Out:
# RandomForestClassifier(min_samples_split=10, random_state=1)

# %%
predictions = rf.predict(test_data[predictors])

# %%
accuracy = accuracy_score(test_data['Simple Target'], predictions)
precision = precision_score(test_data['Simple Target'], predictions, average='weighted')
recall = recall_score(test_data['Simple Target'], predictions, average='weighted')
f1 = f1_score(test_data['Simple Target'], predictions, average='weighted')

# %%
print("Accuracy: ", accuracy)
print("Precision: ", precision)
print("Recall: ", recall)
print("F1: ", f1)
# Out:
# Accuracy:  0.6516079632465543
# Precision:  0.6376315978966559
# Recall:  0.6516079632465543
# F1:  0.6229808893442819

# %%
def objective(trial):
    n_estimators = trial.suggest_int("n_estimators", 200, 500, log=True)
    max_depth = trial.suggest_int("max_depth", 2, 32)
    min_samples_split = trial.suggest_int("min_samples_split", 2, 10)
    min_samples_leaf = trial.suggest_int("min_samples_leaf", 1, 10)
    max_terminal_nodes = trial.suggest_int("max_terminal_nodes", 2, 100)

    rf = RandomForestClassifier(n_estimators=n_estimators, 
                                min_samples_split=min_samples_split, 
                                max_depth=max_depth, 
                                min_samples_leaf=min_samples_leaf, 
                                #max_terminal_nodes=max_terminal_nodes,
                                random_state=1)
    rf.fit(train_data[predictors], train_data['Simple Target'])
    predictions = rf.predict(test_data[predictors])
    return f1_score(test_data['Simple Target'], predictions, average='weighted')

# %%
# Create study object
study = opt.create_study(direction="maximize")

# Run optimization process
study.optimize(objective, n_trials=20, show_progress_bar=True)
# Out:
# [I 2024-09-30 17:23:05,350] A new study created in memory with name: no-name-f44cf008-6397-4817-8adb-8958d6452f4c
#   0%|          | 0/20 [00:00<?, ?it/s]
# [I 2024-09-30 17:23:07,391] Trial 0 finished with value: 0.6290342337883222 and parameters: {'n_estimators': 367, 'max_depth': 13, 'min_samples_split': 10, 'min_samples_leaf': 4, 'max_terminal_nodes': 17}. Best is trial 0 with value: 0.6290342337883222.
# [I 2024-09-30 17:23:08,179] Trial 1 finished with value: 0.6205019479828062 and parameters: {'n_estimators': 289, 'max_depth': 5, 'min_samples_split': 9, 'min_samples_leaf': 10, 'max_terminal_nodes': 48}. Best is trial 0 with value: 0.6290342337883222.
# [I 2024-09-30 17:23:10,581] Trial 2 finished with value: 0.6332032965497589 and parameters: {'n_estimators': 396, 'max_depth': 16, 'min_samples_split': 7, 'min_samples_leaf': 2, 'max_terminal_nodes': 27}. Best is trial 2 with value: 0.6332032965497589.
# [I 2024-09-30 17:23:13,191] Trial 3 finished with value: 0.6267390215992906 and parameters: {'n_estimators': 458, 'max_depth': 24, 'min_samples_split': 10, 'min_samples_leaf': 5, 'max_terminal_nodes': 47}. Best is trial 2 with value: 0.6332032965497589.
# [I 2024-09-30 17:23:15,407] Trial 4 finished with value: 0.6219202331304755 and parameters: {'n_estimators': 392, 'max_depth': 24, 'min_samples_split': 8, 'min_samples_leaf': 5, 'max_terminal_nodes': 18}. Best is trial 2 with value: 0.6332032965497589.
# [I 2024-09-30 17:23:16,961] Trial 5 finished with value: 0.6294531832080904 and parameters: {'n_estimators': 397, 'max_depth': 8, 'min_samples_split': 10, 'min_samples_leaf': 10, 'max_terminal_nodes': 23}. Best is trial 2 with value: 0.6332032965497589.
# [I 2024-09-30 17:23:18,437] Trial 6 finished with value: 0.625074006829977 and parameters: {'n_estimators': 413, 'max_depth': 7, 'min_samples_split': 8, 'min_samples_leaf': 6, 'max_terminal_nodes': 76}. Best is trial 2 with value: 0.6332032965497589.
# [I 2024-09-30 17:23:19,979] Trial 7 finished with value: 0.6211075341812456 and parameters: {'n_estimators': 285, 'max_depth': 15, 'min_samples_split': 8, 'min_samples_leaf': 6, 'max_terminal_nodes': 6}. Best is trial 2 with value: 0.6332032965497589.
# [I 2024-09-30 17:23:21,276] Trial 8 finished with value: 0.6242325042439114 and parameters: {'n_estimators': 211, 'max_depth': 20, 'min_samples_split': 5, 'min_samples_leaf': 3, 'max_terminal_nodes': 53}. Best is trial 2 with value: 0.6332032965497589.
# [I 2024-09-30 17:23:22,662] Trial 9 finished with value: 0.6302810494919104 and parameters: {'n_estimators': 239, 'max_depth': 24, 'min_samples_split': 10, 'min_samples_leaf': 4, 'max_terminal_nodes': 6}. Best is trial 2 with value: 0.6332032965497589.
# [I 2024-09-30 17:23:24,821] Trial 10 finished with value: 0.6297698872845783 and parameters: {'n_estimators': 330, 'max_depth': 32, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_terminal_nodes': 96}. Best is trial 2 with value: 0.6332032965497589.
# [I 2024-09-30 17:23:26,288] Trial 11 finished with value: 0.6272477904943449 and parameters: {'n_estimators': 219, 'max_depth': 29, 'min_samples_split': 6, 'min_samples_leaf': 1, 'max_terminal_nodes': 33}. Best is trial 2 with value: 0.6332032965497589.
# [I 2024-09-30 17:23:27,956] Trial 12 finished with value: 0.6200740994407825 and parameters: {'n_estimators': 251, 'max_depth': 20, 'min_samples_split': 4, 'min_samples_leaf': 1, 'max_terminal_nodes': 4}. Best is trial 2 with value: 0.6332032965497589.
# [I 2024-09-30 17:23:29,197] Trial 13 finished with value: 0.6279892254131356 and parameters: {'n_estimators': 255, 'max_depth': 12, 'min_samples_split': 7, 'min_samples_leaf': 8, 'max_terminal_nodes': 33}. Best is trial 2 with value: 0.6332032965497589.
# [I 2024-09-30 17:23:32,084] Trial 14 finished with value: 0.624638116204307 and parameters: {'n_estimators': 470, 'max_depth': 25, 'min_samples_split': 3, 'min_samples_leaf': 3, 'max_terminal_nodes': 2}. Best is trial 2 with value: 0.6332032965497589.
# [I 2024-09-30 17:23:34,151] Trial 15 finished with value: 0.6338373551540358 and parameters: {'n_estimators': 327, 'max_depth': 19, 'min_samples_split': 6, 'min_samples_leaf': 3, 'max_terminal_nodes': 32}. Best is trial 15 with value: 0.6338373551540358.
# [I 2024-09-30 17:23:36,199] Trial 16 finished with value: 0.6310956853886797 and parameters: {'n_estimators': 326, 'max_depth': 18, 'min_samples_split': 6, 'min_samples_leaf': 2, 'max_terminal_nodes': 64}. Best is trial 15 with value: 0.6338373551540358.
# [I 2024-09-30 17:23:38,105] Trial 17 finished with value: 0.6186513345884659 and parameters: {'n_estimators': 360, 'max_depth': 11, 'min_samples_split': 5, 'min_samples_leaf': 2, 'max_terminal_nodes': 36}. Best is trial 15 with value: 0.6338373551540358.
# [I 2024-09-30 17:23:39,738] Trial 18 finished with value: 0.6115289458913357 and parameters: {'n_estimators': 301, 'max_depth': 17, 'min_samples_split': 7, 'min_samples_leaf': 7, 'max_terminal_nodes': 26}. Best is trial 15 with value: 0.6338373551540358.
# [I 2024-09-30 17:23:42,469] Trial 19 finished with value: 0.63023914270896 and parameters: {'n_estimators': 445, 'max_depth': 20, 'min_samples_split': 5, 'min_samples_leaf': 3, 'max_terminal_nodes': 71}. Best is trial 15 with value: 0.6338373551540358.

# %%
print("Best trial:", study.best_trial)
print("Best hyperparameters:", study.best_params)
# Out:
# Best trial: FrozenTrial(number=15, state=1, values=[0.6338373551540358], datetime_start=datetime.datetime(2024, 9, 30, 17, 23, 32, 85019), datetime_complete=datetime.datetime(2024, 9, 30, 17, 23, 34, 150955), params={'n_estimators': 327, 'max_depth': 19, 'min_samples_split': 6, 'min_samples_leaf': 3, 'max_terminal_nodes': 32}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'n_estimators': IntDistribution(high=500, log=True, low=200, step=1), 'max_depth': IntDistribution(high=32, log=False, low=2, step=1), 'min_samples_split': IntDistribution(high=10, log=False, low=2, step=1), 'min_samples_leaf': IntDistribution(high=10, log=False, low=1, step=1), 'max_terminal_nodes': IntDistribution(high=100, log=False, low=2, step=1)}, trial_id=15, value=None)
# Best hyperparameters: {'n_estimators': 327, 'max_depth': 19, 'min_samples_split': 6, 'min_samples_leaf': 3, 'max_terminal_nodes': 32}

# %%
#get the best params and put them in the model
best_params = study.best_params
rf = RandomForestClassifier(n_estimators=best_params['n_estimators'], 
                            min_samples_split=best_params['min_samples_split'], 
                            max_depth=best_params['max_depth'], 
                            min_samples_leaf=best_params['min_samples_leaf'], 
                            #max_terminal_nodes=max_terminal_nodes,
                            random_state=1)

# %%
#calculate the metrics
rf.fit(train_data[predictors], train_data['Simple Target'])
predictions = rf.predict(test_data[predictors])

# %%
precision = precision_score(test_data['Simple Target'], predictions, average='weighted')
recall = recall_score(test_data['Simple Target'], predictions, average='weighted')
f1 = f1_score(test_data['Simple Target'], predictions, average='weighted')
accuracy = accuracy_score(test_data['Simple Target'], predictions)

# %%
print("Accuracy: ", accuracy)
print("Precision: ", precision)
print("Recall: ", recall)
print("F1: ", f1)
# Out:
# Accuracy:  0.6653905053598775
# Precision:  0.6569554675146235
# Recall:  0.6653905053598775
# F1:  0.6338373551540358

# %%
#Serialize the best params

with open('rf_model_params.pkl', 'wb') as file:
    pkl.dump(best_params, file)
